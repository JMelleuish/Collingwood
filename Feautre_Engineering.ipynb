# %%
import pandas as pd
df = pd.read_csv(r"AFL_Preprocessed.csv")
df.drop(columns="Unnamed: 0")
# Out:
#                   Team  Round HomeAway  FinalScore        Date        Day  \
# 0            Melbourne      1     Home          97  2022-03-16  Wednesday
# 1     Western Bulldogs      1     Away          71  2022-03-16  Wednesday
# 2              Carlton      1     Home         101  2022-03-17   Thursday
# 3             Richmond      1     Away          76  2022-03-17   Thursday
# 4             St Kilda      1     Home          85  2022-03-18     Friday
# ...                ...    ...      ...         ...         ...        ...
# 4373          St Kilda     24     Away          86  2011-09-03   Saturday
# 4374     Port Adelaide     24     Home         112  2011-09-04     Sunday
# 4375         Melbourne     24     Away         104  2011-09-04     Sunday
# 4376          Richmond     24     Home          91  2011-09-04     Sunday
# 4377   North Melbourne     24     Away         104  2011-09-04     Sunday
#
#       Time          Venue  ActualCrowd  Season        Opposition WinLoss  \
# ...

# %% [markdown]
# - Create margin feature
# - Create Last 5 Games feature
